# %% [markdown]
# # Synthetica
# ## Here We Begin
# The first of the Synthetica generative art is simply code sample based on:
# https://github.com/sepandhaghighi/samila
#
# How can we bring embodied conscious awareness into our experiences as enter the metaverse?
#
# Can art transmit that?  Currently, this is a prototype.  How can we inform this generative art with embodied concious awareness?  How do we imbue this with the ephemeral quality of being?

# %%
# Magic
import matplotlib.pyplot as plt
from samila import GenerativeImage
g = GenerativeImage()
g.generate()
g.plot(color="dark green", bgcolor="pink")
plt.show()

# %%
# Basic
import math
import random
def f1(x, y):
    result = random.uniform(-1,1) * x**2  - math.sin(y**2) + abs(y-x)
    return result
def f2(x, y):
    result = random.uniform(-1,1) * y**3 - math.cos(x**2) + 2*x
    return result
g = GenerativeImage(f1, f2)
g.generate()
g.plot()
g.seed
plt.show()

# %%
# Projection
from samila import Projection
g = GenerativeImage(f1, f2)
g.generate()
g.plot(color="black", bgcolor="gold", projection=Projection.DEFAULT)
g.seed
plt.show()

# %%
# Range
g = GenerativeImage(f1, f2)
g.generate(start=-2*math.pi, step=0.01, stop=0)
#g.plot()
g.plot(color="red", bgcolor="white")
g.seed
plt.show()

# %%
# Color
g = GenerativeImage(f1, f2)
g.generate()
g.plot(color="purple", bgcolor="white", projection=Projection.POLAR)
g.seed
plt.show()

# %%
# Regeneration
g = GenerativeImage(f1, f2)
g.generate(seed=1018273)
g.plot(projection=Projection.POLAR)
plt.show()
